# %%
# Importamos las clases que se requieren para manejar los agentes (Agent) y su entorno (Model).
# Cada modelo puede contener múltiples agentes.
from mesa import Agent, Model 

# Debido a que necesitamos que existe un solo agente por celda, elegimos ''SingleGrid''.
from mesa.space import SingleGrid

# Con ''RandomActivation'', hacemos que todos los agentes se activen ''al mismo tiempo''.
from mesa.time import SimultaneousActivation

# Haremos uso de ''DataCollector'' para obtener información de cada paso de la simulación.
from mesa.datacollection import DataCollector

# matplotlib lo usaremos crear una animación de cada uno de los pasos del modelo.
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
plt.rcParams["animation.html"] = "jshtml"
matplotlib.rcParams['animation.embed_limit'] = 2**128

# Importamos los siguientes paquetes para el mejor manejo de valores numéricos.
import numpy as np
import pandas as pd

# Definimos otros paquetes que vamos a usar para medir el tiempo de ejecución de nuestro algoritmo.
import time
import datetime

import sys

# Servidor Python
from http.server import BaseHTTPRequestHandler, HTTPServer
import logging
import json

# %%
def get_grid(model):
    grid = np.zeros( (model.grid.width, model.grid.height) )
    for (content, x, y) in model.grid.coord_iter():
        if content == None:
            grid[x][y] = 0
        else:
            if content.car_malfunction == True:
                grid[x][y] = 200
            else:
                grid[x][y] = 100
    return grid

# %% [markdown]
# # Simmulación 1

# %%
class CarAgent(Agent):
    def __init__(self, unique_id, model, car_malfunction, num_cars_allowed):
        super().__init__(unique_id, model)
        self.velocity = 60
        self.acceleration = 0
        self.brake = 0
        self.sec_distance = 1
        self.intention = self.random.randint(0, 1) #0 left | 1 right
        self.show_intention = False
        self.car_malfunction = car_malfunction
        self.num_cars_allowed = num_cars_allowed
        self.counter = 0
        self.go_forward = False
        self.front_malfunction = False
                   
    def changeLane(self, neighbor):
        neighbor.counter += 1
        neighbor.velocity = 0
        self.show_intention = False
        x, y = self.pos
        self.velocity = 60
        if self.intention == 0:
            if self.model.grid[x - 1][y] == None:
                self.model.grid.move_agent(self, (x - 1, y))
        elif self.intention == 1:
            if self.model.grid[x + 1][y] == None:
                self.model.grid.move_agent(self, (x + 1, y))
            
    def getWaitingCar(self):
        if self.intention == 0:
            waiting_car_pos = (self.pos[0] - 1, self.pos[1] + 1)
        elif self.intention == 1:
            waiting_car_pos = (self.pos[0] + 1, self.pos[1] + 1)
        return waiting_car_pos
    
    def getPassingCar(self):
        if self.pos[0] == 0:
            passing_car = (self.pos[0] + 1, self.pos[1] - 1)
        elif self.pos[0] == 2:
            passing_car = (self.pos[0] - 1, self.pos[1] - 1)
        
        return passing_car
    
    def canPass(self, neighbor):
        if neighbor.show_intention == True:
            intention = neighbor.intention
            carLane = self.pos[0]
            if (intention == 0 and carLane == 0) or (intention == 1 and carLane == 2):
                if self.counter > self.num_cars_allowed:
                    self.velocity = 60
            elif (intention == 0 and carLane == 2) or (intention == 1 and carLane == 0):
                self.velocity = 60
                
    def step(self):
        
        
        neighbors = self.model.grid.get_neighbors(self.pos, moore=True, include_center=False)
        
        if self.car_malfunction == True and self.pos[1] == self.model.grid.height / 2:
            self.velocity = 0
            self.model.accident_occured = True
        elif self.model.accident_occured == True and self.pos[0] == 1 and self.pos[1] == (self.model.grid.height / 2) + 1:
            self.velocity = 0
        elif self.model.accident_occured == True and (self.pos[0] == 0 or self.pos[0] == 2) and self.pos[1] == (self.model.grid.height / 2) + 2:
            self.velocity = 0
        elif self.model.accident_occured == True and (self.pos[0] == 0 or self.pos[0] == 2) and self.pos[1] <= (self.model.grid.height / 2) + 1:
            self.velocity = 60
            
        for neighbor in neighbors:
            if self.pos[0] == 1:
                if neighbor.car_malfunction == True:
                    self.front_malfunction = True
                    self.show_intention = True
                    self.velocity = 0
         
        if self.model.accident_occured == True:
            if self.pos[0] == 1 and self.front_malfunction == True:    
                waiting_car_pos = self.getWaitingCar()
                diagonal_car = self.model.grid[waiting_car_pos[0]][waiting_car_pos[1]]
                if diagonal_car != None:
                    if diagonal_car.counter <= diagonal_car.num_cars_allowed:
                        self.changeLane(diagonal_car)
            elif self.pos[0] == 0 or self.pos[0] == 2 :
                passing_car = self.getPassingCar()
                front_passing_car = self.model.grid[passing_car[0]][passing_car[1]]
                if front_passing_car != None and front_passing_car.front_malfunction == True:
                    self.canPass(front_passing_car)
                elif front_passing_car == None and (self.pos[0] == 0 or self.pos[0] == 2):
                    self.velocity = 60

                    
        if self.velocity == 60 and self.model.grid[self.pos[0]][self.pos[1] - 1] == None:
            self.model.grid.move_agent(self, (self.pos[0], self.pos[1] - 1))

# %%
def get_positions(model):
    positions = []
    for (content, x, y) in model.grid.coord_iter():
        if content != None:
            car_properties = {"id": content.unique_id, "posx": x, "posy": y, "car_malfunction": content.car_malfunction}
            positions.append(car_properties)
    return json.dumps(positions)

# %%
class RoadModel(Model):
    def __init__(self, width, height):
        self.max_velocity = 60
        self.start_time = time.time()
        self.accident_time = datetime.timedelta(seconds=2*60)
        self.schedule = SimultaneousActivation(self)
        self.accident_occured = False
        self.grid = SingleGrid(width, height, False)
        self.id_counter = 0
        self.count_steps = 0
        
        self.datacollector = DataCollector(model_reporters={"Grid":get_grid})
        
    def step(self):
        self.datacollector.collect(self)
        for (content, x, y) in self.grid.coord_iter():
            if content != None and y == 0:
                self.grid.remove_agent(content)
                self.schedule.remove(content)
        
        
        if self.count_steps == 150:
            accidented_car = CarAgent(self.id_counter, self, True, 0)
            x = 1
            y = self.grid.height - 1
            self.grid.place_agent(accidented_car,(x, y))
            self.schedule.add(accidented_car)
            self.id_counter += 1
        else:
            car_spawn = CarAgent(self.id_counter, self, False, self.random.randint(0, 2))
            x = self.random.randint(0, 2)
            y = self.grid.height - 1
            if self.grid[x][y] == None:
                self.grid.place_agent(car_spawn ,(x, y))
                self.schedule.add(car_spawn)
                self.id_counter += 1
        self.count_steps += 1
        self.schedule.step()

# %%
MAX_ITERATIONS = 300
WIDTH = 3
HEIGHT = 30

start_time = time.time()
model = RoadModel(WIDTH, HEIGHT)
for i in range(MAX_ITERATIONS):
    print(get_positions(model))
    model.step()
        
print('Tiempo de ejecución: ', str(datetime.timedelta(seconds=(time.time() - start_time))))
# Out:
# []
# [{"id": 0, "posx": 0, "posy": 28, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 28, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 28, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 27, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 28, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 26, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 27, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 25, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 26, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 24, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 25, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 23, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 24, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 22, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 23, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 21, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 22, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 20, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 21, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 19, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 20, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 28, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 18, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 19, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 27, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 17, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 18, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 26, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 16, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 17, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 25, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 28, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 15, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 16, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 24, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 27, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 14, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 15, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 23, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 26, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 13, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 14, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 22, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 25, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 28, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 12, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 13, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 21, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 24, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 27, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 11, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 12, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 20, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 23, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 26, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 28, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 10, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 7, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 11, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 19, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 22, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 25, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 27, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 9, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 6, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 7, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 10, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 18, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 21, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 24, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 26, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 8, "car_malfunction": false}, {"id": 22, "posx": 2, "posy": 28, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 5, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 6, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 9, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 17, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 20, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 23, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 25, "car_malfunction": false}, {"id": 23, "posx": 1, "posy": 28, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 7, "car_malfunction": false}, {"id": 22, "posx": 2, "posy": 27, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 4, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 5, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 7, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 8, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 16, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 19, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 22, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 24, "car_malfunction": false}, {"id": 23, "posx": 1, "posy": 27, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 6, "car_malfunction": false}, {"id": 22, "posx": 2, "posy": 26, "car_malfunction": false}, {"id": 24, "posx": 2, "posy": 28, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 3, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 4, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 6, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 25, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 7, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 15, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 18, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 21, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 23, "car_malfunction": false}, {"id": 23, "posx": 1, "posy": 26, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 5, "car_malfunction": false}, {"id": 22, "posx": 2, "posy": 25, "car_malfunction": false}, {"id": 24, "posx": 2, "posy": 27, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 2, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 3, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 5, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 7, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 25, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 6, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 14, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 17, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 20, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 22, "car_malfunction": false}, {"id": 23, "posx": 1, "posy": 25, "car_malfunction": false}, {"id": 26, "posx": 1, "posy": 28, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 4, "car_malfunction": false}, {"id": 22, "posx": 2, "posy": 24, "car_malfunction": false}, {"id": 24, "posx": 2, "posy": 26, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 1, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 2, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 4, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 6, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 7, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 25, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 5, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 13, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 16, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 19, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 21, "car_malfunction": false}, {"id": 23, "posx": 1, "posy": 24, "car_malfunction": false}, {"id": 26, "posx": 1, "posy": 27, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 3, "car_malfunction": false}, {"id": 22, "posx": 2, "posy": 23, "car_malfunction": false}, {"id": 24, "posx": 2, "posy": 25, "car_malfunction": false}, {"id": 27, "posx": 2, "posy": 28, "car_malfunction": false}]
# [{"id": 0, "posx": 0, "posy": 0, "car_malfunction": false}, {"id": 1, "posx": 0, "posy": 1, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 3, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 5, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 6, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 7, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 25, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 4, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 12, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 15, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 18, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 20, "car_malfunction": false}, {"id": 23, "posx": 1, "posy": 23, "car_malfunction": false}, {"id": 26, "posx": 1, "posy": 26, "car_malfunction": false}, {"id": 28, "posx": 1, "posy": 28, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 2, "car_malfunction": false}, {"id": 22, "posx": 2, "posy": 22, "car_malfunction": false}, {"id": 24, "posx": 2, "posy": 24, "car_malfunction": false}, {"id": 27, "posx": 2, "posy": 27, "car_malfunction": false}]
# [{"id": 1, "posx": 0, "posy": 0, "car_malfunction": false}, {"id": 3, "posx": 0, "posy": 2, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 4, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 5, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 6, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 7, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 25, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 29, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 3, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 11, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 14, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 17, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 19, "car_malfunction": false}, {"id": 23, "posx": 1, "posy": 22, "car_malfunction": false}, {"id": 26, "posx": 1, "posy": 25, "car_malfunction": false}, {"id": 28, "posx": 1, "posy": 27, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 1, "car_malfunction": false}, {"id": 22, "posx": 2, "posy": 21, "car_malfunction": false}, {"id": 24, "posx": 2, "posy": 23, "car_malfunction": false}, {"id": 27, "posx": 2, "posy": 26, "car_malfunction": false}]
# [{"id": 3, "posx": 0, "posy": 1, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 3, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 4, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 5, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 6, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 7, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 25, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 29, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 30, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 2, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 10, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 13, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 16, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 18, "car_malfunction": false}, {"id": 23, "posx": 1, "posy": 21, "car_malfunction": false}, {"id": 26, "posx": 1, "posy": 24, "car_malfunction": false}, {"id": 28, "posx": 1, "posy": 26, "car_malfunction": false}, {"id": 2, "posx": 2, "posy": 0, "car_malfunction": false}, {"id": 22, "posx": 2, "posy": 20, "car_malfunction": false}, {"id": 24, "posx": 2, "posy": 22, "car_malfunction": false}, {"id": 27, "posx": 2, "posy": 25, "car_malfunction": false}]
# [{"id": 3, "posx": 0, "posy": 0, "car_malfunction": false}, {"id": 5, "posx": 0, "posy": 2, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 3, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 4, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 5, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 6, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 7, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 25, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 29, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 30, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 1, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 9, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 12, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 15, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 17, "car_malfunction": false}, {"id": 23, "posx": 1, "posy": 20, "car_malfunction": false}, {"id": 26, "posx": 1, "posy": 23, "car_malfunction": false}, {"id": 28, "posx": 1, "posy": 25, "car_malfunction": false}, {"id": 31, "posx": 1, "posy": 28, "car_malfunction": false}, {"id": 22, "posx": 2, "posy": 19, "car_malfunction": false}, {"id": 24, "posx": 2, "posy": 21, "car_malfunction": false}, {"id": 27, "posx": 2, "posy": 24, "car_malfunction": false}]
# [{"id": 5, "posx": 0, "posy": 1, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 2, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 3, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 4, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 5, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 6, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 7, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 25, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 29, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 30, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 4, "posx": 1, "posy": 0, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 8, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 11, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 14, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 16, "car_malfunction": false}, {"id": 23, "posx": 1, "posy": 19, "car_malfunction": false}, {"id": 26, "posx": 1, "posy": 22, "car_malfunction": false}, {"id": 28, "posx": 1, "posy": 24, "car_malfunction": false}, {"id": 31, "posx": 1, "posy": 27, "car_malfunction": false}, {"id": 32, "posx": 1, "posy": 28, "car_malfunction": false}, {"id": 22, "posx": 2, "posy": 18, "car_malfunction": false}, {"id": 24, "posx": 2, "posy": 20, "car_malfunction": false}, {"id": 27, "posx": 2, "posy": 23, "car_malfunction": false}]
# [{"id": 5, "posx": 0, "posy": 0, "car_malfunction": false}, {"id": 6, "posx": 0, "posy": 1, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 2, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 3, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 4, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 5, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 6, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 25, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 29, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 30, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 33, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 7, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 10, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 13, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 15, "car_malfunction": false}, {"id": 23, "posx": 1, "posy": 18, "car_malfunction": false}, {"id": 26, "posx": 1, "posy": 21, "car_malfunction": false}, {"id": 28, "posx": 1, "posy": 23, "car_malfunction": false}, {"id": 31, "posx": 1, "posy": 26, "car_malfunction": false}, {"id": 32, "posx": 1, "posy": 27, "car_malfunction": false}, {"id": 22, "posx": 2, "posy": 17, "car_malfunction": false}, {"id": 24, "posx": 2, "posy": 19, "car_malfunction": false}, {"id": 27, "posx": 2, "posy": 22, "car_malfunction": false}]
# [{"id": 6, "posx": 0, "posy": 0, "car_malfunction": false}, {"id": 7, "posx": 0, "posy": 1, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 2, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 3, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 4, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 5, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 7, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 25, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 29, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 30, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 33, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 6, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 9, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 12, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 14, "car_malfunction": false}, {"id": 23, "posx": 1, "posy": 17, "car_malfunction": false}, {"id": 26, "posx": 1, "posy": 20, "car_malfunction": false}, {"id": 28, "posx": 1, "posy": 22, "car_malfunction": false}, {"id": 31, "posx": 1, "posy": 25, "car_malfunction": false}, {"id": 32, "posx": 1, "posy": 26, "car_malfunction": false}, {"id": 22, "posx": 2, "posy": 16, "car_malfunction": false}, {"id": 24, "posx": 2, "posy": 18, "car_malfunction": false}, {"id": 27, "posx": 2, "posy": 21, "car_malfunction": false}, {"id": 34, "posx": 2, "posy": 28, "car_malfunction": false}]
# [{"id": 7, "posx": 0, "posy": 0, "car_malfunction": false}, {"id": 8, "posx": 0, "posy": 1, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 2, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 3, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 4, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 6, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 7, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 25, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 29, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 30, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 33, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 5, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 8, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 11, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 13, "car_malfunction": false}, {"id": 23, "posx": 1, "posy": 16, "car_malfunction": false}, {"id": 26, "posx": 1, "posy": 19, "car_malfunction": false}, {"id": 28, "posx": 1, "posy": 21, "car_malfunction": false}, {"id": 31, "posx": 1, "posy": 24, "car_malfunction": false}, {"id": 32, "posx": 1, "posy": 25, "car_malfunction": false}, {"id": 22, "posx": 2, "posy": 15, "car_malfunction": false}, {"id": 24, "posx": 2, "posy": 17, "car_malfunction": false}, {"id": 27, "posx": 2, "posy": 20, "car_malfunction": false}, {"id": 34, "posx": 2, "posy": 27, "car_malfunction": false}, {"id": 35, "posx": 2, "posy": 28, "car_malfunction": false}]
# [{"id": 8, "posx": 0, "posy": 0, "car_malfunction": false}, {"id": 9, "posx": 0, "posy": 1, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 2, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 3, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 5, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 6, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 25, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 29, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 30, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 33, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 4, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 7, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 10, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 12, "car_malfunction": false}, {"id": 23, "posx": 1, "posy": 15, "car_malfunction": false}, {"id": 26, "posx": 1, "posy": 18, "car_malfunction": false}, {"id": 28, "posx": 1, "posy": 20, "car_malfunction": false}, {"id": 31, "posx": 1, "posy": 23, "car_malfunction": false}, {"id": 32, "posx": 1, "posy": 24, "car_malfunction": false}, {"id": 22, "posx": 2, "posy": 14, "car_malfunction": false}, {"id": 24, "posx": 2, "posy": 16, "car_malfunction": false}, {"id": 27, "posx": 2, "posy": 19, "car_malfunction": false}, {"id": 34, "posx": 2, "posy": 26, "car_malfunction": false}, {"id": 35, "posx": 2, "posy": 27, "car_malfunction": false}, {"id": 36, "posx": 2, "posy": 28, "car_malfunction": false}]
# [{"id": 9, "posx": 0, "posy": 0, "car_malfunction": false}, {"id": 10, "posx": 0, "posy": 1, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 2, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 4, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 5, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 7, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 25, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 29, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 30, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 33, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 3, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 6, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 9, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 11, "car_malfunction": false}, {"id": 23, "posx": 1, "posy": 14, "car_malfunction": false}, {"id": 26, "posx": 1, "posy": 17, "car_malfunction": false}, {"id": 28, "posx": 1, "posy": 19, "car_malfunction": false}, {"id": 31, "posx": 1, "posy": 22, "car_malfunction": false}, {"id": 32, "posx": 1, "posy": 23, "car_malfunction": false}, {"id": 22, "posx": 2, "posy": 13, "car_malfunction": false}, {"id": 24, "posx": 2, "posy": 15, "car_malfunction": false}, {"id": 27, "posx": 2, "posy": 18, "car_malfunction": false}, {"id": 34, "posx": 2, "posy": 25, "car_malfunction": false}, {"id": 35, "posx": 2, "posy": 26, "car_malfunction": false}, {"id": 36, "posx": 2, "posy": 27, "car_malfunction": false}, {"id": 37, "posx": 2, "posy": 28, "car_malfunction": false}]
# [{"id": 10, "posx": 0, "posy": 0, "car_malfunction": false}, {"id": 11, "posx": 0, "posy": 1, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 3, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 4, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 6, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 7, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 25, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 29, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 30, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 33, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 2, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 5, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 8, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 10, "car_malfunction": false}, {"id": 23, "posx": 1, "posy": 13, "car_malfunction": false}, {"id": 26, "posx": 1, "posy": 16, "car_malfunction": false}, {"id": 28, "posx": 1, "posy": 18, "car_malfunction": false}, {"id": 31, "posx": 1, "posy": 21, "car_malfunction": false}, {"id": 32, "posx": 1, "posy": 22, "car_malfunction": false}, {"id": 22, "posx": 2, "posy": 12, "car_malfunction": false}, {"id": 24, "posx": 2, "posy": 14, "car_malfunction": false}, {"id": 27, "posx": 2, "posy": 17, "car_malfunction": false}, {"id": 34, "posx": 2, "posy": 24, "car_malfunction": false}, {"id": 35, "posx": 2, "posy": 25, "car_malfunction": false}, {"id": 36, "posx": 2, "posy": 26, "car_malfunction": false}, {"id": 37, "posx": 2, "posy": 27, "car_malfunction": false}, {"id": 38, "posx": 2, "posy": 28, "car_malfunction": false}]
# [{"id": 11, "posx": 0, "posy": 0, "car_malfunction": false}, {"id": 13, "posx": 0, "posy": 2, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 3, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 5, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 6, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 25, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 29, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 30, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 33, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 1, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 4, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 7, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 9, "car_malfunction": false}, {"id": 23, "posx": 1, "posy": 12, "car_malfunction": false}, {"id": 26, "posx": 1, "posy": 15, "car_malfunction": false}, {"id": 28, "posx": 1, "posy": 17, "car_malfunction": false}, {"id": 31, "posx": 1, "posy": 20, "car_malfunction": false}, {"id": 32, "posx": 1, "posy": 21, "car_malfunction": false}, {"id": 22, "posx": 2, "posy": 11, "car_malfunction": false}, {"id": 24, "posx": 2, "posy": 13, "car_malfunction": false}, {"id": 27, "posx": 2, "posy": 16, "car_malfunction": false}, {"id": 34, "posx": 2, "posy": 23, "car_malfunction": false}, {"id": 35, "posx": 2, "posy": 24, "car_malfunction": false}, {"id": 36, "posx": 2, "posy": 25, "car_malfunction": false}, {"id": 37, "posx": 2, "posy": 26, "car_malfunction": false}, {"id": 38, "posx": 2, "posy": 27, "car_malfunction": false}, {"id": 39, "posx": 2, "posy": 28, "car_malfunction": false}]
# [{"id": 13, "posx": 0, "posy": 1, "car_malfunction": false}, {"id": 14, "posx": 0, "posy": 2, "car_malfunction": false}, {"id": 16, "posx": 0, "posy": 4, "car_malfunction": false}, {"id": 17, "posx": 0, "posy": 5, "car_malfunction": false}, {"id": 19, "posx": 0, "posy": 7, "car_malfunction": false}, {"id": 21, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 25, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 29, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 30, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 33, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 12, "posx": 1, "posy": 0, "car_malfunction": false}, {"id": 15, "posx": 1, "posy": 3, "car_malfunction": false}, {"id": 18, "posx": 1, "posy": 6, "car_malfunction": false}, {"id": 20, "posx": 1, "posy": 8, "car_malfunction": false}, {"id": 23, "posx": 1, "posy": 11, "car_malfunction": false}, {"id": 26, "posx": 1, "posy": 14, "car_malfunction": false}, {"id": 28, "posx": 1, "posy": 16, "car_malfunction": false}, {"id": 31, "posx": 1, "posy": 19, "car_malfunction": false}, {"id": 32, "posx": 1, "posy": 20, "car_malfunction": false}, {"id": 40, "posx": 1, "posy": 28, "car_malfunction": false}, {"id": 22, "posx": 2, "posy": 10, "car_malfunction": false}, {"id": 24, "posx": 2, "posy": 12, "car_malfunction": false}, {"id": 27, "posx": 2, "posy": 15, "car_malfunction": false}, {"id": 34, "posx": 2, "posy": 22, "car_malfunction": false}, {"id": 35, "posx": 2, "posy": 23, "car_malfunction": false}, {"id": 36, "posx": 2, "posy": 24, "car_malfunction": false}, {"id": 37, "posx": 2, "posy": 25, "car_malfunction": false}, {"id": 38, "posx": 2, "posy": 26, "car_malfunction": false}, {"id": 39, "posx": 2, "posy": 27, "car_malfunction": false}]
# ...
# [{"id": 257, "posx": 0, "posy": 0, "car_malfunction": false}, {"id": 253, "posx": 0, "posy": 2, "car_malfunction": false}, {"id": 259, "posx": 0, "posy": 4, "car_malfunction": false}, {"id": 261, "posx": 0, "posy": 5, "car_malfunction": false}, {"id": 267, "posx": 0, "posy": 6, "car_malfunction": false}, {"id": 263, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 268, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 271, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 265, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 275, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 270, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 273, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 277, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 278, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 280, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 287, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 292, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 150, "posx": 1, "posy": 15, "car_malfunction": true}, {"id": 279, "posx": 1, "posy": 16, "car_malfunction": false}, {"id": 284, "posx": 1, "posy": 19, "car_malfunction": false}, {"id": 286, "posx": 1, "posy": 21, "car_malfunction": false}, {"id": 291, "posx": 1, "posy": 26, "car_malfunction": false}, {"id": 293, "posx": 1, "posy": 28, "car_malfunction": false}, {"id": 262, "posx": 2, "posy": 0, "car_malfunction": false}, {"id": 254, "posx": 2, "posy": 2, "car_malfunction": false}, {"id": 256, "posx": 2, "posy": 3, "car_malfunction": false}, {"id": 264, "posx": 2, "posy": 5, "car_malfunction": false}, {"id": 266, "posx": 2, "posy": 8, "car_malfunction": false}, {"id": 269, "posx": 2, "posy": 9, "car_malfunction": false}, {"id": 272, "posx": 2, "posy": 10, "car_malfunction": false}, {"id": 274, "posx": 2, "posy": 12, "car_malfunction": false}, {"id": 276, "posx": 2, "posy": 15, "car_malfunction": false}, {"id": 281, "posx": 2, "posy": 17, "car_malfunction": false}, {"id": 282, "posx": 2, "posy": 18, "car_malfunction": false}, {"id": 283, "posx": 2, "posy": 19, "car_malfunction": false}, {"id": 285, "posx": 2, "posy": 20, "car_malfunction": false}, {"id": 288, "posx": 2, "posy": 23, "car_malfunction": false}, {"id": 289, "posx": 2, "posy": 24, "car_malfunction": false}, {"id": 290, "posx": 2, "posy": 25, "car_malfunction": false}]
# [{"id": 253, "posx": 0, "posy": 1, "car_malfunction": false}, {"id": 259, "posx": 0, "posy": 3, "car_malfunction": false}, {"id": 261, "posx": 0, "posy": 4, "car_malfunction": false}, {"id": 267, "posx": 0, "posy": 5, "car_malfunction": false}, {"id": 263, "posx": 0, "posy": 7, "car_malfunction": false}, {"id": 268, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 271, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 265, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 275, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 270, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 273, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 279, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 277, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 278, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 280, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 287, "posx": 0, "posy": 21, "car_malfunction": false}, {"id": 292, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 150, "posx": 1, "posy": 15, "car_malfunction": true}, {"id": 284, "posx": 1, "posy": 18, "car_malfunction": false}, {"id": 286, "posx": 1, "posy": 20, "car_malfunction": false}, {"id": 291, "posx": 1, "posy": 25, "car_malfunction": false}, {"id": 293, "posx": 1, "posy": 27, "car_malfunction": false}, {"id": 254, "posx": 2, "posy": 1, "car_malfunction": false}, {"id": 256, "posx": 2, "posy": 2, "car_malfunction": false}, {"id": 264, "posx": 2, "posy": 4, "car_malfunction": false}, {"id": 266, "posx": 2, "posy": 7, "car_malfunction": false}, {"id": 269, "posx": 2, "posy": 8, "car_malfunction": false}, {"id": 272, "posx": 2, "posy": 9, "car_malfunction": false}, {"id": 274, "posx": 2, "posy": 11, "car_malfunction": false}, {"id": 276, "posx": 2, "posy": 14, "car_malfunction": false}, {"id": 281, "posx": 2, "posy": 16, "car_malfunction": false}, {"id": 282, "posx": 2, "posy": 17, "car_malfunction": false}, {"id": 283, "posx": 2, "posy": 18, "car_malfunction": false}, {"id": 285, "posx": 2, "posy": 19, "car_malfunction": false}, {"id": 288, "posx": 2, "posy": 22, "car_malfunction": false}, {"id": 289, "posx": 2, "posy": 23, "car_malfunction": false}, {"id": 290, "posx": 2, "posy": 24, "car_malfunction": false}, {"id": 294, "posx": 2, "posy": 28, "car_malfunction": false}]
# [{"id": 253, "posx": 0, "posy": 0, "car_malfunction": false}, {"id": 259, "posx": 0, "posy": 2, "car_malfunction": false}, {"id": 261, "posx": 0, "posy": 3, "car_malfunction": false}, {"id": 267, "posx": 0, "posy": 4, "car_malfunction": false}, {"id": 263, "posx": 0, "posy": 6, "car_malfunction": false}, {"id": 268, "posx": 0, "posy": 7, "car_malfunction": false}, {"id": 271, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 265, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 275, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 270, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 273, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 279, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 277, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 278, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 280, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 287, "posx": 0, "posy": 20, "car_malfunction": false}, {"id": 292, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 295, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 150, "posx": 1, "posy": 15, "car_malfunction": true}, {"id": 284, "posx": 1, "posy": 17, "car_malfunction": false}, {"id": 286, "posx": 1, "posy": 19, "car_malfunction": false}, {"id": 291, "posx": 1, "posy": 24, "car_malfunction": false}, {"id": 293, "posx": 1, "posy": 26, "car_malfunction": false}, {"id": 254, "posx": 2, "posy": 0, "car_malfunction": false}, {"id": 256, "posx": 2, "posy": 1, "car_malfunction": false}, {"id": 264, "posx": 2, "posy": 3, "car_malfunction": false}, {"id": 266, "posx": 2, "posy": 6, "car_malfunction": false}, {"id": 269, "posx": 2, "posy": 7, "car_malfunction": false}, {"id": 272, "posx": 2, "posy": 8, "car_malfunction": false}, {"id": 274, "posx": 2, "posy": 10, "car_malfunction": false}, {"id": 276, "posx": 2, "posy": 13, "car_malfunction": false}, {"id": 281, "posx": 2, "posy": 15, "car_malfunction": false}, {"id": 282, "posx": 2, "posy": 16, "car_malfunction": false}, {"id": 283, "posx": 2, "posy": 17, "car_malfunction": false}, {"id": 285, "posx": 2, "posy": 18, "car_malfunction": false}, {"id": 288, "posx": 2, "posy": 21, "car_malfunction": false}, {"id": 289, "posx": 2, "posy": 22, "car_malfunction": false}, {"id": 290, "posx": 2, "posy": 23, "car_malfunction": false}, {"id": 294, "posx": 2, "posy": 27, "car_malfunction": false}]
# [{"id": 259, "posx": 0, "posy": 1, "car_malfunction": false}, {"id": 261, "posx": 0, "posy": 2, "car_malfunction": false}, {"id": 267, "posx": 0, "posy": 3, "car_malfunction": false}, {"id": 263, "posx": 0, "posy": 5, "car_malfunction": false}, {"id": 268, "posx": 0, "posy": 6, "car_malfunction": false}, {"id": 271, "posx": 0, "posy": 7, "car_malfunction": false}, {"id": 265, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 275, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 270, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 273, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 279, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 277, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 278, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 280, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 287, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 292, "posx": 0, "posy": 24, "car_malfunction": false}, {"id": 295, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 296, "posx": 0, "posy": 28, "car_malfunction": false}, {"id": 150, "posx": 1, "posy": 15, "car_malfunction": true}, {"id": 284, "posx": 1, "posy": 16, "car_malfunction": false}, {"id": 286, "posx": 1, "posy": 18, "car_malfunction": false}, {"id": 291, "posx": 1, "posy": 23, "car_malfunction": false}, {"id": 293, "posx": 1, "posy": 25, "car_malfunction": false}, {"id": 256, "posx": 2, "posy": 0, "car_malfunction": false}, {"id": 264, "posx": 2, "posy": 2, "car_malfunction": false}, {"id": 266, "posx": 2, "posy": 5, "car_malfunction": false}, {"id": 269, "posx": 2, "posy": 6, "car_malfunction": false}, {"id": 272, "posx": 2, "posy": 7, "car_malfunction": false}, {"id": 274, "posx": 2, "posy": 9, "car_malfunction": false}, {"id": 276, "posx": 2, "posy": 12, "car_malfunction": false}, {"id": 281, "posx": 2, "posy": 14, "car_malfunction": false}, {"id": 282, "posx": 2, "posy": 15, "car_malfunction": false}, {"id": 283, "posx": 2, "posy": 16, "car_malfunction": false}, {"id": 285, "posx": 2, "posy": 17, "car_malfunction": false}, {"id": 288, "posx": 2, "posy": 20, "car_malfunction": false}, {"id": 289, "posx": 2, "posy": 21, "car_malfunction": false}, {"id": 290, "posx": 2, "posy": 22, "car_malfunction": false}, {"id": 294, "posx": 2, "posy": 26, "car_malfunction": false}]
# [{"id": 259, "posx": 0, "posy": 0, "car_malfunction": false}, {"id": 261, "posx": 0, "posy": 1, "car_malfunction": false}, {"id": 267, "posx": 0, "posy": 2, "car_malfunction": false}, {"id": 263, "posx": 0, "posy": 4, "car_malfunction": false}, {"id": 268, "posx": 0, "posy": 5, "car_malfunction": false}, {"id": 271, "posx": 0, "posy": 6, "car_malfunction": false}, {"id": 265, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 275, "posx": 0, "posy": 9, "car_malfunction": false}, {"id": 270, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 273, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 279, "posx": 0, "posy": 13, "car_malfunction": false}, {"id": 277, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 284, "posx": 0, "posy": 16, "car_malfunction": false}, {"id": 278, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 280, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 287, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 292, "posx": 0, "posy": 23, "car_malfunction": false}, {"id": 295, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 296, "posx": 0, "posy": 27, "car_malfunction": false}, {"id": 150, "posx": 1, "posy": 15, "car_malfunction": true}, {"id": 286, "posx": 1, "posy": 17, "car_malfunction": false}, {"id": 291, "posx": 1, "posy": 22, "car_malfunction": false}, {"id": 293, "posx": 1, "posy": 24, "car_malfunction": false}, {"id": 264, "posx": 2, "posy": 1, "car_malfunction": false}, {"id": 266, "posx": 2, "posy": 4, "car_malfunction": false}, {"id": 269, "posx": 2, "posy": 5, "car_malfunction": false}, {"id": 272, "posx": 2, "posy": 6, "car_malfunction": false}, {"id": 274, "posx": 2, "posy": 8, "car_malfunction": false}, {"id": 276, "posx": 2, "posy": 11, "car_malfunction": false}, {"id": 281, "posx": 2, "posy": 13, "car_malfunction": false}, {"id": 282, "posx": 2, "posy": 14, "car_malfunction": false}, {"id": 283, "posx": 2, "posy": 15, "car_malfunction": false}, {"id": 285, "posx": 2, "posy": 16, "car_malfunction": false}, {"id": 288, "posx": 2, "posy": 19, "car_malfunction": false}, {"id": 289, "posx": 2, "posy": 20, "car_malfunction": false}, {"id": 290, "posx": 2, "posy": 21, "car_malfunction": false}, {"id": 294, "posx": 2, "posy": 25, "car_malfunction": false}, {"id": 297, "posx": 2, "posy": 28, "car_malfunction": false}]
# [{"id": 261, "posx": 0, "posy": 0, "car_malfunction": false}, {"id": 267, "posx": 0, "posy": 1, "car_malfunction": false}, {"id": 263, "posx": 0, "posy": 3, "car_malfunction": false}, {"id": 268, "posx": 0, "posy": 4, "car_malfunction": false}, {"id": 271, "posx": 0, "posy": 5, "car_malfunction": false}, {"id": 265, "posx": 0, "posy": 7, "car_malfunction": false}, {"id": 275, "posx": 0, "posy": 8, "car_malfunction": false}, {"id": 270, "posx": 0, "posy": 10, "car_malfunction": false}, {"id": 273, "posx": 0, "posy": 11, "car_malfunction": false}, {"id": 279, "posx": 0, "posy": 12, "car_malfunction": false}, {"id": 277, "posx": 0, "posy": 14, "car_malfunction": false}, {"id": 284, "posx": 0, "posy": 15, "car_malfunction": false}, {"id": 278, "posx": 0, "posy": 17, "car_malfunction": false}, {"id": 280, "posx": 0, "posy": 18, "car_malfunction": false}, {"id": 287, "posx": 0, "posy": 19, "car_malfunction": false}, {"id": 292, "posx": 0, "posy": 22, "car_malfunction": false}, {"id": 295, "posx": 0, "posy": 25, "car_malfunction": false}, {"id": 296, "posx": 0, "posy": 26, "car_malfunction": false}, {"id": 150, "posx": 1, "posy": 15, "car_malfunction": true}, {"id": 286, "posx": 1, "posy": 16, "car_malfunction": false}, {"id": 291, "posx": 1, "posy": 21, "car_malfunction": false}, {"id": 293, "posx": 1, "posy": 23, "car_malfunction": false}, {"id": 264, "posx": 2, "posy": 0, "car_malfunction": false}, {"id": 266, "posx": 2, "posy": 3, "car_malfunction": false}, {"id": 269, "posx": 2, "posy": 4, "car_malfunction": false}, {"id": 272, "posx": 2, "posy": 5, "car_malfunction": false}, {"id": 274, "posx": 2, "posy": 7, "car_malfunction": false}, {"id": 276, "posx": 2, "posy": 10, "car_malfunction": false}, {"id": 281, "posx": 2, "posy": 12, "car_malfunction": false}, {"id": 282, "posx": 2, "posy": 13, "car_malfunction": false}, {"id": 283, "posx": 2, "posy": 14, "car_malfunction": false}, {"id": 285, "posx": 2, "posy": 15, "car_malfunction": false}, {"id": 288, "posx": 2, "posy": 18, "car_malfunction": false}, {"id": 289, "posx": 2, "posy": 19, "car_malfunction": false}, {"id": 290, "posx": 2, "posy": 20, "car_malfunction": false}, {"id": 294, "posx": 2, "posy": 24, "car_malfunction": false}, {"id": 297, "posx": 2, "posy": 27, "car_malfunction": false}, {"id": 298, "posx": 2, "posy": 28, "car_malfunction": false}]
# Tiempo de ejecución:  0:00:00.130997

# %%
all_grid = model.datacollector.get_model_vars_dataframe()
pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(all_grid)

# %%
fig, axs = plt.subplots(figsize=(7,7))
axs.set_xticks([])
axs.set_yticks([])

patch = plt.imshow(all_grid.iloc[0][0], cmap=plt.cm.binary, vmin=0, vmax=200)
fig.colorbar(patch, ax=axs)

def animate(i):
    patch.set_data(all_grid.iloc[i][0])
    
anim = animation.FuncAnimation(fig, animate, frames=MAX_ITERATIONS)

# %%
anim

# %% [markdown]
# # Simulación 2

# %%
class CarAgent(Agent):
    def __init__(self, unique_id, model, car_malfunction, num_cars_allowed):
        super().__init__(unique_id, model)
        self.velocity = 60
        self.acceleration = 0
        self.brake = 0
        self.sec_distance = 1
        self.intention = self.random.randint(0, 1) #0 left | 1 right
        self.show_intention = True
        self.car_malfunction = car_malfunction
        self.num_cars_allowed = num_cars_allowed
        self.counter = 0
        self.go_forward = False
        self.front_malfunction = False
                   
    def changeLane(self, neighbor):
        if neighbor != None:
            neighbor.counter += 1
            neighbor.velocity = 0
        self.show_intention = False
        x, y = self.pos
        self.velocity = 60
        if self.intention == 0:
            if self.model.grid[x - 1][y] == None:
                self.model.grid.move_agent(self, (x - 1, y))
        elif self.intention == 1:
            if self.model.grid[x + 1][y] == None:
                self.model.grid.move_agent(self, (x + 1, y))
            
    def getWaitingCar(self):
        if self.intention == 0 and self.pos[1]:
            waiting_car_pos = (self.pos[0] - 1, self.pos[1] + 1)
        elif self.intention == 1 and self.pos[1]:
            waiting_car_pos = (self.pos[0] + 1, self.pos[1] + 1)
        return waiting_car_pos
    
    def getPassingCar(self):
        if self.pos[0] == 0:
            passing_car = (self.pos[0] + 1, self.pos[1] - 1)
        elif self.pos[0] == 2:
            passing_car = (self.pos[0] - 1, self.pos[1] - 1)
        
        return passing_car
    
    def canPass(self, neighbor):
        if neighbor.show_intention == True:
            intention = neighbor.intention
            carLane = self.pos[0]
            if (intention == 0 and carLane == 0) or (intention == 1 and carLane == 2):
                if self.counter > self.num_cars_allowed:
                    self.velocity = 60
            elif (intention == 0 and carLane == 2) or (intention == 1 and carLane == 0):
                self.velocity = 60
                
    def step(self):
        neighbors = self.model.grid.get_neighbors(self.pos, moore=True, include_center=False)
                
        if self.car_malfunction == True and self.pos[1] == (self.model.grid.height / 2):
            self.velocity = 0
            self.model.accident_occured = True
        elif self.model.accident_occured == True and self.pos[1] <= (self.model.grid.height / 2) + 1:
            self.velocity = 60
        elif self.model.accident_occured == True and (self.pos[0] == 0 or self.pos[0] == 2):
            self.velocity = 0
        
        if self.pos[0] == 1 and self.pos[1] == self.model.grid.height - 5 and self.car_malfunction == False:    
            waiting_car_pos = self.getWaitingCar()
            diagonal_car = self.model.grid[waiting_car_pos[0]][waiting_car_pos[1]]
            if diagonal_car != None:
                if diagonal_car.counter <= diagonal_car.num_cars_allowed:
                    self.changeLane(diagonal_car)
            elif diagonal_car == None:
                self.changeLane(diagonal_car)
        elif self.pos[0] == 0 or self.pos[0] == 2 :
            passing_car = self.getPassingCar()
            front_passing_car = self.model.grid[passing_car[0]][passing_car[1]]
            if front_passing_car != None and front_passing_car.front_malfunction == True:
                self.canPass(front_passing_car)
            elif front_passing_car == None and (self.pos[0] == 0 or self.pos[0] == 2):
                self.velocity = 60
  
        if self.velocity == 60 and self.model.grid[self.pos[0]][self.pos[1] - 1] == None:
            self.model.grid.move_agent(self, (self.pos[0], self.pos[1] - 1))

# %%
class RoadModel(Model):
    def __init__(self, width, height):
        self.max_velocity = 60
        self.start_time = time.time()
        self.accident_time = datetime.timedelta(seconds=2*60)
        self.schedule = SimultaneousActivation(self)
        self.accident_occured = False
        self.grid = SingleGrid(width, height, False)
        self.id_counter = 0
        self.count_steps = 0
        
        self.datacollector = DataCollector(model_reporters={"Grid":get_grid})
        
    def step(self):
        self.datacollector.collect(self)
        for (content, x, y) in self.grid.coord_iter():
            if content != None and y == 0:
                self.grid.remove_agent(content)
                self.schedule.remove(content)
        
        if self.count_steps == 150:
            accidented_car = CarAgent(self.id_counter, self, True, 0)
            x = 1
            y = self.grid.height - 1
            self.grid.place_agent(accidented_car,(x, y))
            self.schedule.add(accidented_car)
            self.id_counter += 1
        else:
            car_spawn = CarAgent(self.id_counter, self, False, self.random.randint(0, 2))
            x = self.random.randint(0, 2)
            y = self.grid.height - 1
            if self.grid[x][y] == None:
                self.grid.place_agent(car_spawn ,(x, y))
                self.schedule.add(car_spawn)
                self.id_counter += 1
        self.count_steps += 1
        self.schedule.step()

# %%
MAX_ITERATIONS = 300
WIDTH = 3
HEIGHT = 30

start_time = time.time()
model = RoadModel(WIDTH, HEIGHT)
for i in range(MAX_ITERATIONS):
    model.step()
        
print('Tiempo de ejecución: ', str(datetime.timedelta(seconds=(time.time() - start_time))))

# %%
all_grid = model.datacollector.get_model_vars_dataframe()
pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(all_grid)

# %%
fig, axs = plt.subplots(figsize=(7,7))
axs.set_xticks([])
axs.set_yticks([])

patch = plt.imshow(all_grid.iloc[0][0], cmap=plt.cm.binary, vmin=0, vmax=200)
fig.colorbar(patch, ax=axs)

def animate(i):
    patch.set_data(all_grid.iloc[i][0])
    
anim = animation.FuncAnimation(fig, animate, frames=MAX_ITERATIONS)

# %%
anim
